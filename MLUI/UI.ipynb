# %% [markdown]
# # Single Model

# %%
from tkinter import *
from tkinter import filedialog,messagebox
from tkinter import Label
from joblib import Parallel, delayed
import joblib
import pandas as pd
import sklearn
from sklearn.ensemble import _weight_boosting

def load_model(model_name):
    return joblib.load(model_name)



def model_call():
    data_path = path_entry.get()
    
    #data Reading
    X_test = pd.read_csv(data_path)
    
    #model calling
    model_gb = load_model("Grad.sav")
    
    
    #prediction
    gb_pred  = model_gb.predict(X_test)
    
    
    #sleep dictionary
    sleep_stage_dict = {0:"Deep Sleep", 1:"Light Sleep"}
    
    predicted_entry.delete(0, END)
    predicted_entry.insert(0, sleep_stage_dict[gb_pred[0]])



root = Tk()
root.title("Sleep Stage Classification Foe Single Model")
root.configure(bg="white")


path_label = Label(root, text="Enter Data Path:")
path_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")

path_entry = Entry(root, width=50)
path_entry.grid(row=1, column=0, padx=5, pady=5, sticky="w")


get_info_button = Button(root, text="Go", command=model_call, padx=5, pady=2)
get_info_button.grid(row=1, column=1, padx=5, pady=5, sticky="w")


predicted_label = Label(root, text="Predicted Sleep Stage:")
predicted_label.grid(row=2, column=0, padx=5, pady=5, sticky="w")

predicted_entry = Entry(root, width=50)
predicted_entry.grid(row=3, column=0, padx=5, pady=5, sticky="w")
root.mainloop()

# %% [markdown]
# # Convrting exe

# %%
#!pip install pyinstaller

# !pyinstaller --onefile ui.py
# Out:
# 1346 INFO: PyInstaller: 6.2.0
# 1346 INFO: Python: 3.9.15 (conda)
# 1351 INFO: Platform: Windows-10-10.0.22631-SP0
# 1352 INFO: wrote c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\ui.spec
# 1357 INFO: Extending PYTHONPATH with paths
# ['c:\\Users\\RAZER\\Documents\\GitHub\\Snake_ARC\\MLUI']
# 1649 INFO: checking Analysis
# 1734 INFO: Building because C:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\ui.py changed
# 1734 INFO: Initializing module dependency graph...
# 1734 INFO: Caching module graph hooks...
# 1746 INFO: Analyzing base_library.zip ...
# 4747 INFO: Loading module hook 'hook-encodings.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 6696 INFO: Loading module hook 'hook-pickle.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 7103 INFO: Loading module hook 'hook-heapq.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 7374 INFO: Caching module dependency graph...
# 7486 INFO: Running Analysis Analysis-00.toc
# 7486 INFO: Looking for Python shared library...
# 7494 INFO: Using Python shared library: C:\Users\RAZER\anaconda3\envs\TitanoBoa\python39.dll
# 7494 INFO: Analyzing c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\ui.py
# 7808 INFO: Loading module hook 'hook-platform.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 7820 INFO: Loading module hook 'hook-sysconfig.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 7971 INFO: Loading module hook 'hook-numpy.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Lib\\site-packages\\numpy\\_pyinstaller'...
# 8403 INFO: Loading module hook 'hook-difflib.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 8518 INFO: Loading module hook 'hook-multiprocessing.util.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 8562 INFO: Loading module hook 'hook-xml.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 9058 INFO: Loading module hook 'hook-psutil.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 9895 INFO: Processing pre-safe import module hook distutils from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-distutils.py'.
# 9895 INFO: Processing pre-find module path hook distutils from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-distutils.py'.
# 10373 INFO: Loading module hook 'hook-distutils.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 10896 INFO: Loading module hook 'hook-pandas.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 13293 INFO: Loading module hook 'hook-pytz.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 13484 INFO: Loading module hook 'hook-pkg_resources.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 17403 INFO: Processing pre-safe import module hook six.moves from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-six.moves.py'.
# 18000 INFO: Loading module hook 'hook-scipy.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 18076 INFO: Loading module hook 'hook-pycparser.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 18474 INFO: Loading module hook 'hook-distutils.util.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 18557 INFO: Loading module hook 'hook-setuptools.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 22806 INFO: Loading module hook 'hook-importlib_metadata.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 23001 INFO: Loading module hook 'hook-packaging.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 23613 INFO: Loading module hook 'hook-matplotlib.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 23954 INFO: Processing pre-safe import module hook gi from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-gi.py'.
# 24003 INFO: Loading module hook 'hook-PIL.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 24048 INFO: Loading module hook 'hook-PIL.Image.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 25618 INFO: Loading module hook 'hook-xml.etree.cElementTree.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 25664 INFO: Loading module hook 'hook-xml.dom.domreg.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 26100 INFO: Loading module hook 'hook-PIL.ImageFilter.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 26542 INFO: Loading module hook 'hook-jinja2.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 27237 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 28557 INFO: Loading module hook 'hook-IPython.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 30108 INFO: Loading module hook 'hook-pygments.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 34960 INFO: Loading module hook 'hook-lib2to3.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 35224 INFO: Loading module hook 'hook-wcwidth.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 35936 INFO: Loading module hook 'hook-jedi.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 36741 INFO: Loading module hook 'hook-parso.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 37503 INFO: Loading module hook 'hook-sqlite3.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 39144 INFO: Loading module hook 'hook-nbformat.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 39261 INFO: Loading module hook 'hook-jsonschema.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 39608 INFO: Processing pre-safe import module hook urllib3.packages.six.moves from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-urllib3.packages.six.moves.py'.
# 40034 INFO: Loading module hook 'hook-charset_normalizer.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 40155 INFO: Loading module hook 'hook-cryptography.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 43831 INFO: Loading module hook 'hook-certifi.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 44090 INFO: Loading module hook 'hook-zmq.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 46011 INFO: Loading module hook 'hook-platformdirs.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 46416 INFO: Loading module hook 'hook-shelve.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 46478 INFO: Loading module hook 'hook-scipy.linalg.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 46615 INFO: Loading module hook 'hook-scipy.sparse.csgraph.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 47265 INFO: Loading module hook 'hook-scipy.spatial.transform.rotation.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 48873 INFO: Loading module hook 'hook-pandas.io.formats.style.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 50197 INFO: Loading module hook 'hook-pyarrow.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 50886 INFO: Loading module hook 'hook-pandas.plotting.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 50959 INFO: Loading module hook 'hook-numba.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 51080 INFO: Loading module hook 'hook-llvmlite.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 53679 INFO: Processing pre-safe import module hook win32com from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\pre_safe_import_module\\hook-win32com.py'.
# 53775 INFO: Loading module hook 'hook-win32com.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 53776 INFO: Loading module hook 'hook-pythoncom.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 53844 INFO: Loading module hook 'hook-pywintypes.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 56571 INFO: Loading module hook 'hook-lxml.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 58920 INFO: Loading module hook 'hook-sklearn.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 59237 INFO: Loading module hook 'hook-sklearn.utils.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 59397 INFO: Loading module hook 'hook-sklearn.cluster.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 59405 INFO: Loading module hook 'hook-sklearn.metrics.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 62674 INFO: Loading module hook 'hook-sklearn.metrics.cluster.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 62701 INFO: Loading module hook 'hook-sklearn.metrics.pairwise.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 62795 INFO: Loading module hook 'hook-sklearn.neighbors.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 62891 INFO: Loading module hook 'hook-sklearn.linear_model.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 63567 INFO: Loading module hook 'hook-sklearn.tree.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 63715 INFO: Processing module hooks...
# 63718 INFO: Loading module hook 'hook-lxml.etree.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 63762 INFO: Loading module hook 'hook-lxml.isoschematron.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 63768 WARNING: Hidden import "pyarrow.compat" not found!
# 63769 WARNING: Hidden import "sklearn.neighbors._typedefs" not found!
# 64004 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 64005 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 64308 INFO: Found configured default matplotlib backend: module://matplotlib_inline.backend_inline
# 64308 INFO: Selected matplotlib backends: ['module://matplotlib_inline.backend_inline']
# 64432 INFO: Loading module hook 'hook-PIL.SpiderImagePlugin.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 65886 INFO: Loading module hook 'hook-scipy.special._ellip_harm_2.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 65886 INFO: Loading module hook 'hook-scipy.special._ufuncs.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 65887 INFO: Loading module hook 'hook-scipy.stats._stats.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 65968 INFO: Loading module hook 'hook-setuptools.msvc.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 66466 INFO: Loading module hook 'hook-setuptools._distutils.command.check.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 66551 INFO: Loading module hook 'hook-_tkinter.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 66551 INFO: checking Tree
# 66571 INFO: checking Tree
# 66575 INFO: checking Tree
# 66576 INFO: Loading module hook 'hook-lxml.objectify.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 67854 INFO: Looking for ctypes DLLs
# 67955 INFO: Analyzing run-time hooks ...
# 67969 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_multiprocessing.py'
# 67972 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgutil.py'
# 67974 INFO: Processing pre-find module path hook _pyi_rth_utils from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-_pyi_rth_utils.py'.
# 67976 INFO: Loading module hook 'hook-_pyi_rth_utils.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 67976 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgres.py'
# 67979 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_win32comgenpy.py'
# 67984 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pywintypes.py'
# 67986 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pythoncom.py'
# 67987 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_setuptools.py'
# 67989 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_traitlets.py'
# 67990 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_mplconfig.py'
# 67991 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_inspect.py'
# 67993 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth__tkinter.py'
# 68154 INFO: Looking for dynamic libraries
# C:\Users\RAZER\anaconda3\envs\TitanoBoa\lib\site-packages\PyInstaller\building\build_main.py:194: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(package)
# C:\Users\RAZER\anaconda3\envs\TitanoBoa\lib\site-packages\PyInstaller\isolated\_child.py:96: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   while run_next_command(read_fh, write_fh):
# 71492 INFO: Extra DLL search directories (AddDllDirectory): []
# 71492 INFO: Extra DLL search directories (PATH): []
# 75392 WARNING: Library not found: could not resolve 'impi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_intelmpi_lp64.1.dll'.
# 75392 WARNING: Library not found: could not resolve 'msmpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_msmpi_ilp64.1.dll'.
# 75392 WARNING: Library not found: could not resolve 'mpich2mpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_mpich2_ilp64.1.dll'.
# 75393 WARNING: Library not found: could not resolve 'mpich2mpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_mpich2_lp64.1.dll'.
# 75393 WARNING: Library not found: could not resolve 'msmpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_msmpi_lp64.1.dll'.
# 75393 WARNING: Library not found: could not resolve 'pgmath.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_pgi_thread.1.dll'.
# 75393 WARNING: Library not found: could not resolve 'pgc.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_pgi_thread.1.dll'.
# 75393 WARNING: Library not found: could not resolve 'pgf90.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_pgi_thread.1.dll'.
# 75393 WARNING: Library not found: could not resolve 'impi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_intelmpi_ilp64.1.dll'.
# 75676 INFO: Warnings written to c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\build\ui\warn-ui.txt
# 76055 INFO: Graph cross-reference written to c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\build\ui\xref-ui.html
# 76233 INFO: checking PYZ
# 76454 INFO: checking PKG
# 76535 INFO: Building because toc changed
# 76535 INFO: Building PKG (CArchive) ui.pkg
# 166806 INFO: Building PKG (CArchive) ui.pkg completed successfully.
# 166891 INFO: Bootloader C:\Users\RAZER\anaconda3\envs\TitanoBoa\lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\run.exe
# 166891 INFO: checking EXE
# 166958 INFO: Building because toc changed
# 166958 INFO: Building EXE from EXE-00.toc
# 166985 INFO: Copying bootloader EXE to c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\dist\ui.exe
# 167065 INFO: Copying icon to EXE
# 167133 INFO: Copying 0 resources to EXE
# 167133 INFO: Embedding manifest in EXE
# 167208 INFO: Appending PKG archive to EXE
# 167406 INFO: Fixing EXE headers
# 169061 INFO: Building EXE from EXE-00.toc completed successfully.

# %% [markdown]
# # Multiple Model Compare

# %%
from tkinter import *
from tkinter import filedialog,messagebox
from tkinter import Label
from joblib import Parallel, delayed
import joblib
import pandas as pd
import sklearn
from sklearn.ensemble import _weight_boosting



def load_model(model_name):
    return joblib.load(model_name)



def model_call():
    
    data_path = path_entry.get()
    
    #data Reading
    df = pd.read_csv(data_path)
    
    y=df["Sleep_Stage"]
    
    X_test = df.loc[:,df.columns!="Sleep_Stage"]
    
    #model calling
    model_ada = load_model("Ada.sav")
    model_gb = load_model("Grad.sav")
    model_rf  = load_model("rf.sav")
    model_knn  = load_model("knn.sav")
    model_hb  = load_model("hb.sav")
    
    
    
    #prediction
    ada_pred = model_ada.predict(X_test)
    gb_pred  = model_gb.predict(X_test)
    rf_pred  = model_rf.predict(X_test)
    knn_pred  = model_knn.predict(X_test)
    hb_pred  = model_hb.predict(X_test)
    
    
    
    #sleep dictionary
    sleep_stage_dict = {0:"Deep Sleep", 1:"Light Sleep"}
    
    expected=0

    predicted_entry.delete(0, END)
    predicted_entry.insert(0, sleep_stage_dict[y[0]])
    ada_entry.delete(0, END)
    ada_entry.insert(0, sleep_stage_dict[ada_pred[0]])
    gb_entry.delete(0, END)
    gb_entry.insert(0, sleep_stage_dict[gb_pred[0]])
    knn_entry.delete(0, END)
    knn_entry.insert(0, sleep_stage_dict[knn_pred[0]])
    rf_entry.delete(0, END)
    rf_entry.insert(0, sleep_stage_dict[rf_pred[0]])
    hb_entry.delete(0, END)
    hb_entry.insert(0, sleep_stage_dict[hb_pred[0]])





root = Tk()
root.title("Sleep Stage Classification")
root.configure(bg="white")


# Label and Entry for Playlist URL
path_label = Label(root, text="Enter Data Path:")
path_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")

path_entry = Entry(root, width=50)
path_entry.grid(row=1, column=0, padx=5, pady=5, sticky="w")

# Button to get playlist info
get_info_button = Button(root, text="Predict", command=model_call, padx=5, pady=2)
get_info_button.grid(row=1, column=1, padx=5, pady=5, sticky="w")

# Labels and Entries for Playlist Info
predicted_label = Label(root, text="Predicted Sleep Stage:")
predicted_label.grid(row=2, column=0, padx=5, pady=5, sticky="w")

predicted_entry = Entry(root, width=50)
predicted_entry.grid(row=3, column=0, padx=5, pady=5, sticky="w")


ada_label = Label(root, text="Ada Boosting:")
ada_label.grid(row=2, column=1, padx=5, pady=5, sticky="w")

ada_entry = Entry(root, width=10)
ada_entry.grid(row=3, column=1, padx=5, pady=5, sticky="w")

gb_label = Label(root, text="Gradient Boosting:")
gb_label.grid(row=2, column=2, padx=5, pady=5, sticky="w")

gb_entry = Entry(root, width=10)
gb_entry.grid(row=3, column=2, padx=5, pady=5, sticky="w")

knn_label = Label(root, text="KNN:")
knn_label.grid(row=2, column=3, padx=5, pady=5, sticky="w")

knn_entry = Entry(root, width=20)
knn_entry.grid(row=3, column=3, padx=5, pady=5, sticky="w")

rf_label = Label(root, text="Random Forest:")
rf_label.grid(row=4, column=1, padx=5, pady=5, sticky="w")

rf_entry = Entry(root, width=10)
rf_entry.grid(row=5, column=1, padx=5, pady=5, sticky="w")

hb_label = Label(root, text="Histogram Boosting:")
hb_label.grid(row=4, column=2, padx=5, pady=5, sticky="w")

hb_entry = Entry(root, width=10)
hb_entry.grid(row=5, column=2, padx=5, pady=5, sticky="w")

root.mainloop()

# %%
df = pd.read_csv("dataset_new.csv")
df = pd.read_csv("row1.csv")

# %%
df.shape[0]
# Out:
# 1
