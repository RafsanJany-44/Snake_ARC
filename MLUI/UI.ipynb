# %%
from joblib import Parallel, delayed
import joblib
import pandas as pd


def load_model(model_name):
    return joblib.load(model_name)


model = load_model("Ada.sav")



X_test = pd.read_csv("test_1.csv")


y_pred = model.predict(X_test)

# %%
X_test.iloc[0:1,:].to_csv("test_1.csv",index=False)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
#!pip install pyinstaller

# !pyinstaller --onefile UI.py
# Out:
# 1392 INFO: PyInstaller: 6.2.0
# 1392 INFO: Python: 3.9.15 (conda)
# 1399 INFO: Platform: Windows-10-10.0.22631-SP0
# 1399 INFO: wrote c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\UI.spec
# 1408 INFO: Extending PYTHONPATH with paths
# ['c:\\Users\\RAZER\\Documents\\GitHub\\Snake_ARC\\MLUI']
# 1811 INFO: checking Analysis
# 1811 INFO: Building Analysis because Analysis-00.toc is non existent
# 1812 INFO: Initializing module dependency graph...
# 1812 INFO: Caching module graph hooks...
# 1824 INFO: Analyzing base_library.zip ...
# 4852 INFO: Loading module hook 'hook-heapq.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 4997 INFO: Loading module hook 'hook-encodings.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 6929 INFO: Loading module hook 'hook-pickle.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 7652 INFO: Caching module dependency graph...
# 7746 INFO: Running Analysis Analysis-00.toc
# 7746 INFO: Looking for Python shared library...
# 7753 INFO: Using Python shared library: C:\Users\RAZER\anaconda3\envs\TitanoBoa\python39.dll
# 7753 INFO: Analyzing c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\UI.py
# 8051 INFO: Loading module hook 'hook-platform.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 8097 INFO: Loading module hook 'hook-sysconfig.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 8241 INFO: Loading module hook 'hook-numpy.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Lib\\site-packages\\numpy\\_pyinstaller'...
# 8706 INFO: Loading module hook 'hook-difflib.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 8806 INFO: Loading module hook 'hook-multiprocessing.util.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 8852 INFO: Loading module hook 'hook-xml.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 9327 INFO: Loading module hook 'hook-psutil.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 10025 INFO: Processing pre-safe import module hook distutils from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-distutils.py'.
# 10025 INFO: Processing pre-find module path hook distutils from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-distutils.py'.
# 10563 INFO: Loading module hook 'hook-distutils.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 11116 INFO: Loading module hook 'hook-pandas.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 13491 INFO: Loading module hook 'hook-pytz.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 13667 INFO: Loading module hook 'hook-pkg_resources.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 17163 INFO: Processing pre-safe import module hook six.moves from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-six.moves.py'.
# 17704 INFO: Loading module hook 'hook-scipy.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 17777 INFO: Loading module hook 'hook-pycparser.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 18093 INFO: Loading module hook 'hook-distutils.util.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 18161 INFO: Loading module hook 'hook-setuptools.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 22128 INFO: Loading module hook 'hook-importlib_metadata.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 22291 INFO: Loading module hook 'hook-packaging.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 22833 INFO: Loading module hook 'hook-matplotlib.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 23161 INFO: Processing pre-safe import module hook gi from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-gi.py'.
# 23207 INFO: Loading module hook 'hook-PIL.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 23248 INFO: Loading module hook 'hook-PIL.Image.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 24743 INFO: Loading module hook 'hook-xml.etree.cElementTree.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 24783 INFO: Loading module hook 'hook-xml.dom.domreg.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 25170 INFO: Loading module hook 'hook-PIL.ImageFilter.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 25560 INFO: Loading module hook 'hook-jinja2.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 26142 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 27376 INFO: Loading module hook 'hook-IPython.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 28691 INFO: Loading module hook 'hook-pygments.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 33456 INFO: Loading module hook 'hook-lib2to3.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 33718 INFO: Loading module hook 'hook-wcwidth.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 34360 INFO: Loading module hook 'hook-jedi.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 35043 INFO: Loading module hook 'hook-parso.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 35759 INFO: Loading module hook 'hook-sqlite3.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 37227 INFO: Loading module hook 'hook-nbformat.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 37332 INFO: Loading module hook 'hook-jsonschema.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 37673 INFO: Processing pre-safe import module hook urllib3.packages.six.moves from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-urllib3.packages.six.moves.py'.
# 38046 INFO: Loading module hook 'hook-charset_normalizer.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 38126 INFO: Loading module hook 'hook-cryptography.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 41452 INFO: Loading module hook 'hook-certifi.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 41685 INFO: Loading module hook 'hook-zmq.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 43554 INFO: Loading module hook 'hook-platformdirs.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 43965 INFO: Loading module hook 'hook-shelve.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 44030 INFO: Loading module hook 'hook-scipy.linalg.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 44172 INFO: Loading module hook 'hook-scipy.sparse.csgraph.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 44812 INFO: Loading module hook 'hook-scipy.spatial.transform.rotation.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 46380 INFO: Loading module hook 'hook-pandas.io.formats.style.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 47712 INFO: Loading module hook 'hook-pyarrow.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 48265 INFO: Loading module hook 'hook-pandas.plotting.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 48489 INFO: Loading module hook 'hook-numba.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 48587 INFO: Loading module hook 'hook-llvmlite.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 51112 INFO: Processing pre-safe import module hook win32com from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\pre_safe_import_module\\hook-win32com.py'.
# 51183 INFO: Loading module hook 'hook-win32com.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 51184 INFO: Loading module hook 'hook-pythoncom.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 51255 INFO: Loading module hook 'hook-pywintypes.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 53792 INFO: Loading module hook 'hook-lxml.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 55940 INFO: Loading module hook 'hook-sklearn.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 56241 INFO: Loading module hook 'hook-sklearn.utils.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 56518 INFO: Loading module hook 'hook-sklearn.cluster.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 56530 INFO: Loading module hook 'hook-sklearn.metrics.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 59855 INFO: Loading module hook 'hook-sklearn.metrics.cluster.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 59878 INFO: Loading module hook 'hook-sklearn.metrics.pairwise.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 59973 INFO: Loading module hook 'hook-sklearn.neighbors.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 60136 INFO: Loading module hook 'hook-sklearn.linear_model.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 60776 INFO: Loading module hook 'hook-sklearn.tree.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 61005 INFO: Processing module hooks...
# 61009 INFO: Loading module hook 'hook-lxml.etree.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 61052 INFO: Loading module hook 'hook-lxml.isoschematron.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 61058 WARNING: Hidden import "pyarrow.compat" not found!
# 61059 WARNING: Hidden import "sklearn.neighbors._typedefs" not found!
# 61225 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 61226 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 61517 INFO: Found configured default matplotlib backend: module://matplotlib_inline.backend_inline
# 61517 INFO: Selected matplotlib backends: ['module://matplotlib_inline.backend_inline']
# 61646 INFO: Loading module hook 'hook-PIL.SpiderImagePlugin.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 63228 INFO: Loading module hook 'hook-scipy.special._ellip_harm_2.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 63228 INFO: Loading module hook 'hook-scipy.special._ufuncs.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 63229 INFO: Loading module hook 'hook-scipy.stats._stats.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 63246 INFO: Loading module hook 'hook-setuptools.msvc.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 63731 INFO: Loading module hook 'hook-setuptools._distutils.command.check.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 63826 INFO: Loading module hook 'hook-_tkinter.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 63827 INFO: checking Tree
# 63827 INFO: Building Tree because Tree-00.toc is non existent
# 63827 INFO: Building Tree Tree-00.toc
# 63857 INFO: checking Tree
# 63857 INFO: Building Tree because Tree-01.toc is non existent
# 63857 INFO: Building Tree Tree-01.toc
# 63862 INFO: checking Tree
# 63862 INFO: Building Tree because Tree-02.toc is non existent
# 63862 INFO: Building Tree Tree-02.toc
# 63863 INFO: Loading module hook 'hook-lxml.objectify.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 65612 INFO: Looking for ctypes DLLs
# 65712 INFO: Analyzing run-time hooks ...
# 65727 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_multiprocessing.py'
# 65730 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgutil.py'
# 65732 INFO: Processing pre-find module path hook _pyi_rth_utils from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-_pyi_rth_utils.py'.
# 65733 INFO: Loading module hook 'hook-_pyi_rth_utils.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 65734 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgres.py'
# 65737 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_win32comgenpy.py'
# 65744 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pywintypes.py'
# 65745 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pythoncom.py'
# 65747 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_setuptools.py'
# 65748 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_traitlets.py'
# 65749 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_mplconfig.py'
# 65751 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_inspect.py'
# 65752 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth__tkinter.py'
# 65977 INFO: Looking for dynamic libraries
# C:\Users\RAZER\anaconda3\envs\TitanoBoa\lib\site-packages\PyInstaller\building\build_main.py:194: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(package)
# C:\Users\RAZER\anaconda3\envs\TitanoBoa\lib\site-packages\PyInstaller\isolated\_child.py:96: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   while run_next_command(read_fh, write_fh):
# 69774 INFO: Extra DLL search directories (AddDllDirectory): []
# 69774 INFO: Extra DLL search directories (PATH): []
# 73252 WARNING: Library not found: could not resolve 'impi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_intelmpi_ilp64.1.dll'.
# 73252 WARNING: Library not found: could not resolve 'mpich2mpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_mpich2_ilp64.1.dll'.
# 73252 WARNING: Library not found: could not resolve 'pgf90.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_pgi_thread.1.dll'.
# 73252 WARNING: Library not found: could not resolve 'pgc.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_pgi_thread.1.dll'.
# 73252 WARNING: Library not found: could not resolve 'pgmath.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_pgi_thread.1.dll'.
# 73252 WARNING: Library not found: could not resolve 'impi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_intelmpi_lp64.1.dll'.
# 73252 WARNING: Library not found: could not resolve 'mpich2mpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_mpich2_lp64.1.dll'.
# 73252 WARNING: Library not found: could not resolve 'msmpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_msmpi_lp64.1.dll'.
# 73252 WARNING: Library not found: could not resolve 'msmpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_msmpi_ilp64.1.dll'.
# 73487 INFO: Warnings written to c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\build\UI\warn-UI.txt
# 73846 INFO: Graph cross-reference written to c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\build\UI\xref-UI.html
# 74008 INFO: checking PYZ
# 74008 INFO: Building PYZ because PYZ-00.toc is non existent
# 74008 INFO: Building PYZ (ZlibArchive) c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\build\UI\PYZ-00.pyz
# 77312 INFO: Building PYZ (ZlibArchive) c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\build\UI\PYZ-00.pyz completed successfully.
# 77436 INFO: checking PKG
# 77437 INFO: Building PKG because PKG-00.toc is non existent
# 77437 INFO: Building PKG (CArchive) UI.pkg
# 158933 INFO: Building PKG (CArchive) UI.pkg completed successfully.
# 159014 INFO: Bootloader C:\Users\RAZER\anaconda3\envs\TitanoBoa\lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\run.exe
# 159014 INFO: checking EXE
# 159014 INFO: Building EXE because EXE-00.toc is non existent
# 159014 INFO: Building EXE from EXE-00.toc
# 159014 INFO: Copying bootloader EXE to c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\dist\UI.exe
# 159137 INFO: Copying icon to EXE
# 159277 INFO: Copying 0 resources to EXE
# 159277 INFO: Embedding manifest in EXE
# 159408 INFO: Appending PKG archive to EXE
# 159577 INFO: Fixing EXE headers
# 161409 INFO: Building EXE from EXE-00.toc completed successfully.

# %%
from tkinter import *
from tkinter import filedialog,messagebox
from tkinter import Label
from joblib import Parallel, delayed
import joblib
import pandas as pd
import sklearn
from sklearn.ensemble import _weight_boosting

def load_model(model_name):
    return joblib.load(model_name)



def model_call():
    
    data_path = playlist_url_entry.get()
    
    model = load_model("Ada.sav")
    X_test = pd.read_csv(data_path)
    y_pred = model.predict(X_test)
    
    sleep_stage_dict = {0:"Deep Sleep", 1:"Light Sleep"}
    
    total_views = 0
    total_likes = 0
    total_comments = 0
    total_duration = 0




    print('Total Viwes: ',total_views)
    print('Total Likes: ',total_likes)
    print('Total comments: ',total_comments)
    print('Total duration: ',total_duration)
    print("Data Path: ",data_path)
    #_________________________________________________________________________________________
    #________________________________________________________________________________________________
    
    playlist_info_entry.delete(0, END)
    playlist_info_entry.insert(0, sleep_stage_dict[y_pred[0]])
    views_entry.delete(0, END)
    views_entry.insert(0, total_views)
    likes_entry.delete(0, END)
    likes_entry.insert(0, total_likes)
    comments_entry.delete(0, END)
    comments_entry.insert(0, total_comments)
    duration_entry.delete(0, END)
    duration_entry.insert(0, str(total_duration))





root = Tk()
root.title("Sleep Stage Classification")
root.configure(bg="white")


# Label and Entry for Playlist URL
playlist_url_label = Label(root, text="Enter Playlist URL:")
playlist_url_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")

playlist_url_entry = Entry(root, width=50)
playlist_url_entry.grid(row=1, column=0, padx=5, pady=5, sticky="w")

# Button to get playlist info
get_info_button = Button(root, text="Go", command=model_call, padx=5, pady=2)
get_info_button.grid(row=1, column=1, padx=5, pady=5, sticky="w")

# Labels and Entries for Playlist Info
playlist_info_label = Label(root, text="Playlist Title:")
playlist_info_label.grid(row=2, column=0, padx=5, pady=5, sticky="w")

playlist_info_entry = Entry(root, width=50)
playlist_info_entry.grid(row=3, column=0, padx=5, pady=5, sticky="w")

views_label = Label(root, text="Total Views:")
views_label.grid(row=2, column=1, padx=5, pady=5, sticky="w")

views_entry = Entry(root, width=10)
views_entry.grid(row=3, column=1, padx=5, pady=5, sticky="w")

likes_label = Label(root, text="Total Likes:")
likes_label.grid(row=2, column=2, padx=5, pady=5, sticky="w")

likes_entry = Entry(root, width=10)
likes_entry.grid(row=3, column=2, padx=5, pady=5, sticky="w")

comments_label = Label(root, text="Total Comments:")
comments_label.grid(row=4, column=0, padx=5, pady=5, sticky="w")

comments_entry = Entry(root, width=10)
comments_entry.grid(row=5, column=0, padx=5, pady=5, sticky="w")

duration_label = Label(root, text="Total Duration:")
duration_label.grid(row=2, column=3, padx=5, pady=5, sticky="w")

duration_entry = Entry(root, width=20)
duration_entry.grid(row=3, column=3, padx=5, pady=5, sticky="w")

pos_comments_label = Label(root, text="Total Positive Comments:")
pos_comments_label.grid(row=4, column=1, padx=5, pady=5, sticky="w")

pos_comments_entry = Entry(root, width=10, bg="green")
pos_comments_entry.grid(row=5, column=1, padx=5, pady=5, sticky="w")

neg_comments_label = Label(root, text="Total Negative Comments:")
neg_comments_label.grid(row=4, column=2, padx=5, pady=5, sticky="w")

neg_comments_entry = Entry(root, width=10, bg="red")
neg_comments_entry.grid(row=5, column=2, padx=5, pady=5, sticky="w")

benchmark_label = Label(root, text="Benchmark:")
benchmark_label.grid(row=6, column=1, pady=5, sticky="w")

benchmark_entry = Entry(root, width=10, bg="yellow")
benchmark_entry.grid(row=7, column=1, pady=5, sticky="w")
root.mainloop()
