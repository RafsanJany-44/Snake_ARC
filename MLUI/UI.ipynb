# %% [markdown]
# # Single Model

# %%
from tkinter import *
from tkinter import filedialog,messagebox
from tkinter import Label
from joblib import Parallel, delayed
import joblib
import pandas as pd
import sklearn
from sklearn.ensemble import _weight_boosting

def load_model(model_name):
    return joblib.load(model_name)



def model_call():
    data_path = path_entry.get()
    
    #data Reading
    X_test = pd.read_csv(data_path)
    
    #model calling
    model_gb = load_model("Grad.sav")
    
    
    #prediction
    gb_pred  = model_gb.predict(X_test)
    
    
    #sleep dictionary
    sleep_stage_dict = {0:"Deep Sleep", 1:"Light Sleep"}
    
    predicted_entry.delete(0, END)
    predicted_entry.insert(0, sleep_stage_dict[gb_pred[0]])



root = Tk()
root.title("Sleep Stage Classification Foe Single Model")
root.configure(bg="white")


path_label = Label(root, text="Enter Data Path:")
path_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")

path_entry = Entry(root, width=50)
path_entry.grid(row=1, column=0, padx=5, pady=5, sticky="w")


get_info_button = Button(root, text="Go", command=model_call, padx=5, pady=2)
get_info_button.grid(row=1, column=1, padx=5, pady=5, sticky="w")


predicted_label = Label(root, text="Predicted Sleep Stage:")
predicted_label.grid(row=2, column=0, padx=5, pady=5, sticky="w")

predicted_entry = Entry(root, width=50)
predicted_entry.grid(row=3, column=0, padx=5, pady=5, sticky="w")
root.mainloop()

# %% [markdown]
# # Convrting exe

# %%
#!pip install pyinstaller

# !pyinstaller --onefile UI.py
# Out:
# 1405 INFO: PyInstaller: 6.2.0
# 1405 INFO: Python: 3.9.15 (conda)
# 1411 INFO: Platform: Windows-10-10.0.22631-SP0
# 1413 INFO: wrote c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\UI.spec
# 1419 INFO: Extending PYTHONPATH with paths
# ['c:\\Users\\RAZER\\Documents\\GitHub\\Snake_ARC\\MLUI']
# 1742 INFO: checking Analysis
# 1742 INFO: Building Analysis because Analysis-00.toc is non existent
# 1742 INFO: Initializing module dependency graph...
# 1742 INFO: Caching module graph hooks...
# 1753 INFO: Analyzing base_library.zip ...
# 4860 INFO: Loading module hook 'hook-encodings.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 6744 INFO: Loading module hook 'hook-pickle.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 7256 INFO: Loading module hook 'hook-heapq.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 7464 INFO: Caching module dependency graph...
# 7549 INFO: Running Analysis Analysis-00.toc
# 7549 INFO: Looking for Python shared library...
# 7555 INFO: Using Python shared library: C:\Users\RAZER\anaconda3\envs\TitanoBoa\python39.dll
# 7555 INFO: Analyzing c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\UI.py
# 7865 INFO: Loading module hook 'hook-platform.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 7877 INFO: Loading module hook 'hook-sysconfig.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 8015 INFO: Loading module hook 'hook-numpy.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Lib\\site-packages\\numpy\\_pyinstaller'...
# 8442 INFO: Loading module hook 'hook-difflib.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 8539 INFO: Loading module hook 'hook-multiprocessing.util.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 8584 INFO: Loading module hook 'hook-xml.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 9050 INFO: Loading module hook 'hook-psutil.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 9769 INFO: Processing pre-safe import module hook distutils from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-distutils.py'.
# 9770 INFO: Processing pre-find module path hook distutils from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-distutils.py'.
# 10302 INFO: Loading module hook 'hook-distutils.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 10800 INFO: Loading module hook 'hook-pandas.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 13176 INFO: Loading module hook 'hook-pytz.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 13345 INFO: Loading module hook 'hook-pkg_resources.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 16805 INFO: Processing pre-safe import module hook six.moves from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-six.moves.py'.
# 17343 INFO: Loading module hook 'hook-scipy.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 17407 INFO: Loading module hook 'hook-pycparser.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 17720 INFO: Loading module hook 'hook-distutils.util.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 17788 INFO: Loading module hook 'hook-setuptools.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 21640 INFO: Loading module hook 'hook-importlib_metadata.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 21801 INFO: Loading module hook 'hook-packaging.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 22349 INFO: Loading module hook 'hook-matplotlib.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 22653 INFO: Processing pre-safe import module hook gi from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-gi.py'.
# 22696 INFO: Loading module hook 'hook-PIL.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 22735 INFO: Loading module hook 'hook-PIL.Image.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 24100 INFO: Loading module hook 'hook-xml.etree.cElementTree.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 24140 INFO: Loading module hook 'hook-xml.dom.domreg.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 24532 INFO: Loading module hook 'hook-PIL.ImageFilter.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 24903 INFO: Loading module hook 'hook-jinja2.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 25481 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 26693 INFO: Loading module hook 'hook-IPython.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 27962 INFO: Loading module hook 'hook-pygments.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 32570 INFO: Loading module hook 'hook-lib2to3.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 32818 INFO: Loading module hook 'hook-wcwidth.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 33475 INFO: Loading module hook 'hook-jedi.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 34093 INFO: Loading module hook 'hook-parso.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 34800 INFO: Loading module hook 'hook-sqlite3.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 36244 INFO: Loading module hook 'hook-nbformat.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 36352 INFO: Loading module hook 'hook-jsonschema.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 36681 INFO: Processing pre-safe import module hook urllib3.packages.six.moves from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-urllib3.packages.six.moves.py'.
# 37054 INFO: Loading module hook 'hook-charset_normalizer.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 37133 INFO: Loading module hook 'hook-cryptography.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 40391 INFO: Loading module hook 'hook-certifi.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 40621 INFO: Loading module hook 'hook-zmq.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 42529 INFO: Loading module hook 'hook-platformdirs.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 42945 INFO: Loading module hook 'hook-shelve.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 43008 INFO: Loading module hook 'hook-scipy.linalg.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 43149 INFO: Loading module hook 'hook-scipy.sparse.csgraph.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 43770 INFO: Loading module hook 'hook-scipy.spatial.transform.rotation.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 45335 INFO: Loading module hook 'hook-pandas.io.formats.style.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 46588 INFO: Loading module hook 'hook-pyarrow.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 47066 INFO: Loading module hook 'hook-pandas.plotting.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 47292 INFO: Loading module hook 'hook-numba.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 47385 INFO: Loading module hook 'hook-llvmlite.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 49853 INFO: Processing pre-safe import module hook win32com from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\pre_safe_import_module\\hook-win32com.py'.
# 49921 INFO: Loading module hook 'hook-win32com.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 49922 INFO: Loading module hook 'hook-pythoncom.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 49996 INFO: Loading module hook 'hook-pywintypes.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 52446 INFO: Loading module hook 'hook-lxml.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 54535 INFO: Loading module hook 'hook-sklearn.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 54854 INFO: Loading module hook 'hook-sklearn.utils.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 55085 INFO: Loading module hook 'hook-sklearn.cluster.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 55095 INFO: Loading module hook 'hook-sklearn.metrics.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 58143 INFO: Loading module hook 'hook-sklearn.metrics.cluster.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 58168 INFO: Loading module hook 'hook-sklearn.metrics.pairwise.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 58259 INFO: Loading module hook 'hook-sklearn.neighbors.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 58426 INFO: Loading module hook 'hook-sklearn.linear_model.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 59029 INFO: Loading module hook 'hook-sklearn.tree.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 61656 INFO: Processing module hooks...
# 61658 INFO: Loading module hook 'hook-lxml.etree.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 61696 INFO: Loading module hook 'hook-lxml.isoschematron.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 61702 WARNING: Hidden import "pyarrow.compat" not found!
# 61703 WARNING: Hidden import "sklearn.neighbors._typedefs" not found!
# 61866 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 61866 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 62148 INFO: Found configured default matplotlib backend: module://matplotlib_inline.backend_inline
# 62148 INFO: Selected matplotlib backends: ['module://matplotlib_inline.backend_inline']
# 62344 INFO: Loading module hook 'hook-PIL.SpiderImagePlugin.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 63832 INFO: Loading module hook 'hook-scipy.special._ellip_harm_2.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 63833 INFO: Loading module hook 'hook-scipy.special._ufuncs.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 63833 INFO: Loading module hook 'hook-scipy.stats._stats.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 63850 INFO: Loading module hook 'hook-setuptools.msvc.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 64324 INFO: Loading module hook 'hook-setuptools._distutils.command.check.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 64415 INFO: Loading module hook 'hook-_tkinter.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 64416 INFO: checking Tree
# 64416 INFO: Building Tree because Tree-00.toc is non existent
# 64416 INFO: Building Tree Tree-00.toc
# 64445 INFO: checking Tree
# 64445 INFO: Building Tree because Tree-01.toc is non existent
# 64446 INFO: Building Tree Tree-01.toc
# 64449 INFO: checking Tree
# 64449 INFO: Building Tree because Tree-02.toc is non existent
# 64449 INFO: Building Tree Tree-02.toc
# 64450 INFO: Loading module hook 'hook-lxml.objectify.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 65736 INFO: Looking for ctypes DLLs
# 65845 INFO: Analyzing run-time hooks ...
# 65862 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgutil.py'
# 65866 INFO: Processing pre-find module path hook _pyi_rth_utils from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-_pyi_rth_utils.py'.
# 65868 INFO: Loading module hook 'hook-_pyi_rth_utils.py' from 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks'...
# 65869 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_inspect.py'
# 65872 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_multiprocessing.py'
# 65874 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgres.py'
# 65877 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_win32comgenpy.py'
# 65882 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pywintypes.py'
# 65883 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pythoncom.py'
# 65884 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_setuptools.py'
# 65885 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_traitlets.py'
# 65887 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_mplconfig.py'
# 65889 INFO: Including run-time hook 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth__tkinter.py'
# 66118 INFO: Looking for dynamic libraries
# C:\Users\RAZER\anaconda3\envs\TitanoBoa\lib\site-packages\PyInstaller\building\build_main.py:194: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(package)
# C:\Users\RAZER\anaconda3\envs\TitanoBoa\lib\site-packages\PyInstaller\isolated\_child.py:96: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   while run_next_command(read_fh, write_fh):
# 70132 INFO: Extra DLL search directories (AddDllDirectory): ['C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa']
# 70133 INFO: Extra DLL search directories (PATH): []
# 73977 WARNING: Library not found: could not resolve 'mpich2mpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_mpich2_lp64.1.dll'.
# 73977 WARNING: Library not found: could not resolve 'msmpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_msmpi_lp64.1.dll'.
# 73978 WARNING: Library not found: could not resolve 'impi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_intelmpi_ilp64.1.dll'.
# 73978 WARNING: Library not found: could not resolve 'mpich2mpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_mpich2_ilp64.1.dll'.
# 73978 WARNING: Library not found: could not resolve 'msmpi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_msmpi_ilp64.1.dll'.
# 73978 WARNING: Library not found: could not resolve 'pgf90.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_pgi_thread.1.dll'.
# 73978 WARNING: Library not found: could not resolve 'pgc.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_pgi_thread.1.dll'.
# 73978 WARNING: Library not found: could not resolve 'pgmath.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_pgi_thread.1.dll'.
# 73978 WARNING: Library not found: could not resolve 'impi.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\Library\\bin\\mkl_blacs_intelmpi_lp64.1.dll'.
# 73978 WARNING: Library not found: could not resolve 'cuTENSOR.dll', dependency of 'C:\\Users\\RAZER\\anaconda3\\envs\\TitanoBoa\\lib\\site-packages\\cupy_backends\\cuda\\libs\\cutensor.cp39-win_amd64.pyd'.
# 74244 INFO: Warnings written to c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\build\UI\warn-UI.txt
# 74593 INFO: Graph cross-reference written to c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\build\UI\xref-UI.html
# 74755 INFO: checking PYZ
# 74755 INFO: Building PYZ because PYZ-00.toc is non existent
# 74755 INFO: Building PYZ (ZlibArchive) c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\build\UI\PYZ-00.pyz
# 78102 INFO: Building PYZ (ZlibArchive) c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\build\UI\PYZ-00.pyz completed successfully.
# 78228 INFO: checking PKG
# 78228 INFO: Building PKG because PKG-00.toc is non existent
# 78228 INFO: Building PKG (CArchive) UI.pkg
# 256568 INFO: Building PKG (CArchive) UI.pkg completed successfully.
# 256646 INFO: Bootloader C:\Users\RAZER\anaconda3\envs\TitanoBoa\lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\run.exe
# 256646 INFO: checking EXE
# 256646 INFO: Building EXE because EXE-00.toc is non existent
# 256646 INFO: Building EXE from EXE-00.toc
# 256646 INFO: Copying bootloader EXE to c:\Users\RAZER\Documents\GitHub\Snake_ARC\MLUI\dist\UI.exe
# 256788 INFO: Copying icon to EXE
# 256921 INFO: Copying 0 resources to EXE
# 256922 INFO: Embedding manifest in EXE
# 257080 INFO: Appending PKG archive to EXE
# 257664 INFO: Fixing EXE headers
# 262356 INFO: Building EXE from EXE-00.toc completed successfully.

# %% [markdown]
# # Multiple Model Compare

# %%
from tkinter import *
from tkinter import filedialog,messagebox
from tkinter import Label
from joblib import Parallel, delayed
import joblib
import pandas as pd
import sklearn
from sklearn.ensemble import _weight_boosting
import xgboost as xgb


def load_model(model_name):
    return joblib.load(model_name)



def model_call():
    
    data_path = path_entry.get()
    
    #data Reading
    X_test = pd.read_csv(data_path)
    
    
    
    #model calling
    model_ada = load_model("Ada.sav")
    model_gb = load_model("Grad.sav")
    model_xgb = load_model("xgb.sav")
    model_rf  = load_model("rf.sav")
    model_knn  = load_model("knn.sav")
    model_hb  = load_model("hb.sav")
    
    
    
    #prediction
    ada_pred = model_ada.predict(X_test)
    gb_pred  = model_gb.predict(X_test)
    xgb_pred  = model_xgb.predict(X_test)
    rf_pred  = model_rf.predict(X_test)
    knn_pred  = model_knn.predict(X_test)
    hb_pred  = model_hb.predict(X_test)
    
    
    
    #sleep dictionary
    sleep_stage_dict = {0:"Deep Sleep", 1:"Light Sleep"}
    
    expected=0

    predicted_entry.delete(0, END)
    predicted_entry.insert(0, expected)
    ada_entry.delete(0, END)
    ada_entry.insert(0, sleep_stage_dict[ada_pred[0]])
    gb_entry.delete(0, END)
    gb_entry.insert(0, sleep_stage_dict[gb_pred[0]])
    knn_entry.delete(0, END)
    knn_entry.insert(0, sleep_stage_dict[knn_pred[0]])
    xgb_entry.delete(0, END)
    xgb_entry.insert(0, sleep_stage_dict[xgb_pred[0]])
    rf_entry.delete(0, END)
    rf_entry.insert(0, sleep_stage_dict[rf_pred[0]])
    hb_entry.delete(0, END)
    hb_entry.insert(0, sleep_stage_dict[hb_pred[0]])





root = Tk()
root.title("Sleep Stage Classification")
root.configure(bg="white")


# Label and Entry for Playlist URL
path_label = Label(root, text="Enter Data Path:")
path_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")

path_entry = Entry(root, width=50)
path_entry.grid(row=1, column=0, padx=5, pady=5, sticky="w")

# Button to get playlist info
get_info_button = Button(root, text="Predict", command=model_call, padx=5, pady=2)
get_info_button.grid(row=1, column=1, padx=5, pady=5, sticky="w")

# Labels and Entries for Playlist Info
predicted_label = Label(root, text="Predicted Sleep Stage:")
predicted_label.grid(row=2, column=0, padx=5, pady=5, sticky="w")

predicted_entry = Entry(root, width=50)
predicted_entry.grid(row=3, column=0, padx=5, pady=5, sticky="w")


ada_label = Label(root, text="Ada Boosting:")
ada_label.grid(row=2, column=1, padx=5, pady=5, sticky="w")

ada_entry = Entry(root, width=10)
ada_entry.grid(row=3, column=1, padx=5, pady=5, sticky="w")

gb_label = Label(root, text="Gradient Boosting:")
gb_label.grid(row=2, column=2, padx=5, pady=5, sticky="w")

gb_entry = Entry(root, width=10)
gb_entry.grid(row=3, column=2, padx=5, pady=5, sticky="w")

knn_label = Label(root, text="KNN:")
knn_label.grid(row=4, column=0, padx=5, pady=5, sticky="w")

knn_entry = Entry(root, width=10)
knn_entry.grid(row=5, column=0, padx=5, pady=5, sticky="w")

xgb_label = Label(root, text="XG Boosting:")
xgb_label.grid(row=2, column=3, padx=5, pady=5, sticky="w")

xgb_entry = Entry(root, width=20)
xgb_entry.grid(row=3, column=3, padx=5, pady=5, sticky="w")

rf_label = Label(root, text="Random Forest:")
rf_label.grid(row=4, column=1, padx=5, pady=5, sticky="w")

rf_entry = Entry(root, width=10)
rf_entry.grid(row=5, column=1, padx=5, pady=5, sticky="w")

hb_label = Label(root, text="Histogram Boosting:")
hb_label.grid(row=4, column=2, padx=5, pady=5, sticky="w")

hb_entry = Entry(root, width=10)
hb_entry.grid(row=5, column=2, padx=5, pady=5, sticky="w")

root.mainloop()

# %%
# !python UI.py
